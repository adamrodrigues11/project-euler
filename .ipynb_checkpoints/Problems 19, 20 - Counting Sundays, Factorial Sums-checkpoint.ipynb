# %%
from math import factorial

fact_100 = str(factorial(100))
sum_fact_100 = sum([int(k) for k in fact_100])
sum_fact_100
# Out:
# 648

# %%
count = 0 # initialize the counter
rem = 2 # start on a Tuesday (let Sunday be considered remainder 0)
n = 1901 # initialize the year
days_in_month = [31, days_in_feb, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

while n < 2001:
    days_in_feb = 29 if ((n % 4 == 0) and ( (n % 100 != 0) or (n % 400 == 0))) else 28 # leap years accounted for
    for i in range(len(days_in_month)):
        if rem == 0:
            count += 1
        print("Year: ", n, "Month: ", i, "Day (0 = Sunday): ", rem)
        rem = (rem + (days_in_month[i] % 7)) % 7 
    n += 1

count
# Out:
# Year:  1901 Month:  0 Day (0 = Sunday):  2
# Year:  1901 Month:  1 Day (0 = Sunday):  5
# Year:  1901 Month:  2 Day (0 = Sunday):  6
# Year:  1901 Month:  3 Day (0 = Sunday):  2
# Year:  1901 Month:  4 Day (0 = Sunday):  4
# Year:  1901 Month:  5 Day (0 = Sunday):  0
# Year:  1901 Month:  6 Day (0 = Sunday):  2
# Year:  1901 Month:  7 Day (0 = Sunday):  5
# Year:  1901 Month:  8 Day (0 = Sunday):  1
# Year:  1901 Month:  9 Day (0 = Sunday):  3
# Year:  1901 Month:  10 Day (0 = Sunday):  6
# Year:  1901 Month:  11 Day (0 = Sunday):  1
# Year:  1902 Month:  0 Day (0 = Sunday):  4
# Year:  1902 Month:  1 Day (0 = Sunday):  0
# Year:  1902 Month:  2 Day (0 = Sunday):  1
# Year:  1902 Month:  3 Day (0 = Sunday):  4
# Year:  1902 Month:  4 Day (0 = Sunday):  6
# Year:  1902 Month:  5 Day (0 = Sunday):  2
# Year:  1902 Month:  6 Day (0 = Sunday):  4
# Year:  1902 Month:  7 Day (0 = Sunday):  0
# Year:  1902 Month:  8 Day (0 = Sunday):  3
# Year:  1902 Month:  9 Day (0 = Sunday):  5
# ...
